# %%
from models.honeycomb import Honeycomb_Hamiltonian
from models.square import Square_Hamiltonian

from models.plotting import Plotting_Functions

# %% [markdown]
# CASE 1: W = 0, phi = 1/3

# %%
Square = Square_Hamiltonian(mode = 'specific', t=1, W=0, max_q= None, L = 20, p=1, q=3, save=False)
Square_outputs = Square.prepare_outputs()
square_plot = Plotting_Functions(Square_outputs, save = False)


square_plot.plot_pr(save = False)

square_plot.plot_density_of_states(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'specific', t=1, W=0, max_q= None, L = 20, p=1, q=3, save=False)
honeycomb_outputs = Honeycomb.prepare_outputs()
honeycomb_plot = Plotting_Functions(honeycomb_outputs, save = True)

honeycomb_plot.plot_pr(save = False)

honeycomb_plot.plot_density_of_states(save = False)

# %% [markdown]
# CASE 2: W = 0.1, phi = 1/3

# %%
Square = Square_Hamiltonian(mode = 'specific', t=1, W=0.1, max_q= None, L = 20, p=1, q=3, save=False)
Square_outputs = Square.prepare_outputs()
square_plot = Plotting_Functions(Square_outputs, save = False)


square_plot.plot_pr(save = False)

square_plot.plot_density_of_states(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'specific', t=1, W=0.1, max_q= None, L = 20, p=1, q=3, save=False)
honeycomb_outputs = Honeycomb.prepare_outputs()
honeycomb_plot = Plotting_Functions(honeycomb_outputs, save = True)

honeycomb_plot.plot_pr(save = False)

honeycomb_plot.plot_density_of_states(save = False)

# %% [markdown]
# CASE 3: W = 0.3, phi = 1/3

# %%
Square = Square_Hamiltonian(mode = 'specific', t=1, W=0.3, max_q= None, L = 20, p=1, q=3, save=False)
Square_outputs = Square.prepare_outputs()
square_plot = Plotting_Functions(Square_outputs, save = False)


square_plot.plot_pr(save = False)

square_plot.plot_density_of_states(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'specific', t=1, W=0.3, max_q= None, L = 20, p=1, q=3, save=False)
honeycomb_outputs = Honeycomb.prepare_outputs()
honeycomb_plot = Plotting_Functions(honeycomb_outputs, save = True)

honeycomb_plot.plot_pr(save = False)

honeycomb_plot.plot_density_of_states(save = False)

# %% [markdown]
# CASE 4: W = 0.5, phi = 1/3

# %%
Square = Square_Hamiltonian(mode = 'specific', t=1, W=0.5, max_q= None, L = 20, p=1, q=3, save=False)
Square_outputs = Square.prepare_outputs()
square_plot = Plotting_Functions(Square_outputs, save = False)


square_plot.plot_pr(save = False)

square_plot.plot_density_of_states(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'specific', t=1, W=0.5, max_q= None, L = 20, p=1, q=3, save=False)
honeycomb_outputs = Honeycomb.prepare_outputs()
honeycomb_plot = Plotting_Functions(honeycomb_outputs, save = True)

honeycomb_plot.plot_pr(save = False)

honeycomb_plot.plot_density_of_states(save = False)

# %% [markdown]
# CASE 5: W = 0.8, phi = 1/3

# %%
Square = Square_Hamiltonian(mode = 'specific', t=1, W=0.8, max_q= None, L = 20, p=1, q=3, save=False)
Square_outputs = Square.prepare_outputs()
square_plot = Plotting_Functions(Square_outputs, save = False)


square_plot.plot_pr(save = False)

square_plot.plot_density_of_states(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'specific', t=1, W=0.8, max_q= None, L = 20, p=1, q=3, save=False)
honeycomb_outputs = Honeycomb.prepare_outputs()
honeycomb_plot = Plotting_Functions(honeycomb_outputs, save = True)

honeycomb_plot.plot_pr(save = False)

honeycomb_plot.plot_density_of_states(save = False)

# %% [markdown]
# Square + Honeycomb butterflies at W = {0, 0.1, 0.3, 0.5, 0.8} panels

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'butterfly', t=1, W=0, max_q=31, L = None, p=0, q=0, save=False)
Honeycomb.plot_hofstadter_butterfly(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'butterfly', t=1, W=0.1, max_q=31, L = None, p=0, q=0, save=False)
Honeycomb.plot_hofstadter_butterfly(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'butterfly', t=1, W=0.3, max_q=31, L = None, p=0, q=0, save=False)
Honeycomb.plot_hofstadter_butterfly(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'butterfly', t=1, W=0.5, max_q=31, L = None, p=0, q=0, save=False)
Honeycomb.plot_hofstadter_butterfly(save = False)

# %%
Honeycomb = Honeycomb_Hamiltonian(mode = 'butterfly', t=1, W=0.8, max_q=31, L = None, p=0, q=0, save=False)
Honeycomb.plot_hofstadter_butterfly(save = False)

# %%
square = Square_Hamiltonian(mode = 'butterfly', t=1, W=0, max_q=47, L = None, p=0, q=0, save=False)
square.plot_hofstadter_butterfly(save = False)

# %%
square = Square_Hamiltonian(mode = 'butterfly', t=1, W=0.1, max_q=47, L = None, p=0, q=0, save=False)
square.plot_hofstadter_butterfly(save = False)

# %%
square = Square_Hamiltonian(mode = 'butterfly', t=1, W=0.3, max_q=47, L = None, p=0, q=0, save=False)
square.plot_hofstadter_butterfly(save = False)

# %%
square = Square_Hamiltonian(mode = 'butterfly', t=1, W=0.5, max_q=47, L = None, p=0, q=0, save=False)
square.plot_hofstadter_butterfly(save = False)

# %%
square = Square_Hamiltonian(mode = 'butterfly', t=1, W=0.8, max_q=47, L = None, p=0, q=0, save=False)
square.plot_hofstadter_butterfly(save = False)
